# %%
#import the random module 
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt 
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from citipy import citipy
import time
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5272\619991601.py in <module>
#       9
#      10 # Import the API key.
# ---> 11 from config import weather_api_key
#      12 from citipy import citipy
#      13 import time
#
# ModuleNotFoundError: No module named 'config'

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the lats and longs to a list 
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop Through all the cities in our list 

for i, city in enumerate(cities):
    # group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count =1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | port alfred
# Processing Record 1 of Set 2 | lake saint louis
# Processing Record 1 of Set 2 | clyde river
# Processing Record 1 of Set 2 | cape town
# Processing Record 1 of Set 2 | hilo
# Processing Record 1 of Set 2 | esperance
# Processing Record 1 of Set 2 | lakes entrance
# Processing Record 1 of Set 2 | chapais
# Processing Record 1 of Set 2 | anaconda
# Processing Record 1 of Set 2 | kamskiye polyany
# Processing Record 1 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 2 | haines junction
# Processing Record 1 of Set 2 | chicama
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | nagornskiy
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | vaini
# Processing Record 1 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 2 | grand gaube
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 1 of Set 2 | albany
# Processing Record 1 of Set 2 | katsuura
# Processing Record 1 of Set 2 | fukue
# Processing Record 1 of Set 2 | hermanus
# Processing Record 1 of Set 2 | koumra
# Processing Record 1 of Set 2 | constitucion
# Processing Record 1 of Set 2 | soyo
# Processing Record 1 of Set 2 | east london
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 1 of Set 2 | tabou
# Processing Record 1 of Set 2 | tuatapere
# Processing Record 1 of Set 2 | keetmanshoop
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 1 of Set 2 | lebu
# Processing Record 1 of Set 2 | bluff
# Processing Record 1 of Set 2 | busselton
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 1 of Set 2 | jackson
# Processing Record 1 of Set 2 | cayenne
# Processing Record 1 of Set 2 | tiksi
# Processing Record 1 of Set 2 | avera
# Processing Record 1 of Set 2 | faya
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 1 of Set 2 | kamenka
# Processing Record 1 of Set 2 | kapaa
# Processing Record 1 of Set 2 | atuona
# Processing Record 1 of Set 2 | lukang
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 1 of Set 2 | gunjur
# Processing Record 1 of Set 2 | airai
# Processing Record 1 of Set 3 | san luis
# Processing Record 1 of Set 3 | san patricio
# Processing Record 1 of Set 3 | rawson
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 1 of Set 3 | chuy
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | manacor
# Processing Record 1 of Set 3 | duluth
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 1 of Set 3 | kalmunai
# Processing Record 1 of Set 3 | ati
# Processing Record 1 of Set 3 | korcula
# Processing Record 1 of Set 3 | samarkand
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 1 of Set 3 | mataura
# Processing Record 1 of Set 3 | avarua
# Processing Record 1 of Set 3 | rikitea
# Processing Record 1 of Set 3 | safaga
# Processing Record 1 of Set 3 | jamestown
# Processing Record 1 of Set 3 | belaya gora
# Processing Record 1 of Set 3 | butaritari
# Processing Record 1 of Set 3 | zarate
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 1 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 3 | korla
# Processing Record 1 of Set 3 | batouri
# Processing Record 1 of Set 3 | mitsamiouli
# Processing Record 1 of Set 3 | alamos
# Processing Record 1 of Set 3 | kendari
# Processing Record 1 of Set 3 | quatre cocos
# Processing Record 1 of Set 3 | cidreira
# Processing Record 1 of Set 3 | victoria
# Processing Record 1 of Set 3 | aklavik
# Processing Record 1 of Set 3 | wanganui
# Processing Record 1 of Set 3 | warrnambool
# Processing Record 1 of Set 3 | fortuna
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 1 of Set 3 | botou
# Processing Record 1 of Set 3 | ishinomaki
# Processing Record 1 of Set 3 | severo-yeniseyskiy
# Processing Record 1 of Set 3 | grootfontein
# Processing Record 1 of Set 3 | barrow
# Processing Record 1 of Set 3 | kavieng
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 1 of Set 3 | luderitz
# Processing Record 1 of Set 3 | mehamn
# Processing Record 1 of Set 3 | castro
# Processing Record 1 of Set 3 | lamin
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | san cristobal
# Processing Record 1 of Set 4 | isangel
# Processing Record 1 of Set 4 | beloha
# Processing Record 1 of Set 4 | nishihara
# Processing Record 1 of Set 4 | port blair
# Processing Record 1 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 4 | meulaboh
# Processing Record 1 of Set 4 | muriti
# Processing Record 1 of Set 4 | chegdomyn
# Processing Record 1 of Set 4 | alice springs
# Processing Record 1 of Set 4 | lethem
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | chiredzi
# Processing Record 1 of Set 4 | iquique
# Processing Record 1 of Set 4 | khasan
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 1 of Set 4 | les cayes
# Processing Record 1 of Set 4 | yar-sale
# Processing Record 1 of Set 4 | cockburn town
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 1 of Set 4 | qasigiannguit
# Processing Record 1 of Set 4 | bend
# Processing Record 1 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | leshukonskoye
# Processing Record 1 of Set 4 | betafo
# Processing Record 1 of Set 4 | gorontalo
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 4 | kodiak
# Processing Record 1 of Set 4 | ilinskiy
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 1 of Set 4 | hamilton
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 1 of Set 4 | tres barras
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 1 of Set 4 | boali
# Processing Record 1 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 4 | malanje
# Processing Record 1 of Set 4 | aksu
# Processing Record 1 of Set 4 | mapimi
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 1 of Set 4 | vanavara
# Processing Record 1 of Set 4 | hobart
# Processing Record 1 of Set 4 | burnie
# Processing Record 1 of Set 4 | chaupal
# Processing Record 1 of Set 4 | jieshi
# Processing Record 1 of Set 4 | talnakh
# Processing Record 1 of Set 4 | kaitong
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 1 of Set 4 | salinopolis
# Processing Record 1 of Set 5 | geraldton
# Processing Record 1 of Set 5 | wanning
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 1 of Set 5 | hualmay
# Processing Record 1 of Set 5 | yerbogachen
# Processing Record 1 of Set 5 | lagoa
# Processing Record 1 of Set 5 | bambanglipuro
# Processing Record 1 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 5 | pacifica
# Processing Record 1 of Set 5 | dikson
# Processing Record 1 of Set 5 | narsaq
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 1 of Set 5 | sobolevo
# Processing Record 1 of Set 5 | norman wells
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 5 | kahului
# Processing Record 1 of Set 5 | komsomolskiy
# Processing Record 1 of Set 5 | cuddapah
# Processing Record 1 of Set 5 | serenje
# Processing Record 1 of Set 5 | erenhot
# Processing Record 1 of Set 5 | mnogovershinnyy
# Processing Record 1 of Set 5 | cururupu
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 1 of Set 5 | pafos
# Processing Record 1 of Set 5 | te anau
# Processing Record 1 of Set 5 | plymouth
# Processing Record 1 of Set 5 | sunbury
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 1 of Set 5 | grindavik
# Processing Record 1 of Set 5 | uaua
# Processing Record 1 of Set 5 | georgetown
# Processing Record 1 of Set 5 | panguna
# Processing Record 1 of Set 5 | sandnessjoen
# Processing Record 1 of Set 5 | kununurra
# Processing Record 1 of Set 5 | ancud
# Processing Record 1 of Set 5 | leh
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 5 | bethel
# Processing Record 1 of Set 5 | harper
# Processing Record 1 of Set 5 | oil city
# Processing Record 1 of Set 5 | yellowknife
# Processing Record 1 of Set 5 | vao
# Processing Record 1 of Set 5 | saint anthony
# Processing Record 1 of Set 5 | khatanga
# Processing Record 1 of Set 5 | baiyin
# Processing Record 1 of Set 5 | gurupa
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 1 of Set 5 | danville
# Processing Record 1 of Set 5 | pietersburg
# Processing Record 1 of Set 6 | dwarka
# Processing Record 1 of Set 6 | san pedro
# Processing Record 1 of Set 6 | namatanai
# Processing Record 1 of Set 6 | le port
# Processing Record 1 of Set 6 | dunedin
# Processing Record 1 of Set 6 | barranca
# Processing Record 1 of Set 6 | darnah
# Processing Record 1 of Set 6 | kenai
# Processing Record 1 of Set 6 | colac
# Processing Record 1 of Set 6 | asau
# Processing Record 1 of Set 6 | laguna
# Processing Record 1 of Set 6 | port-gentil
# Processing Record 1 of Set 6 | sambava
# Processing Record 1 of Set 6 | benguela
# Processing Record 1 of Set 6 | sitka
# Processing Record 1 of Set 6 | linguere
# Processing Record 1 of Set 6 | ampanihy
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 6 | mayor pablo lagerenza
# Processing Record 1 of Set 6 | ishigaki
# Processing Record 1 of Set 6 | bridlington
# Processing Record 1 of Set 6 | cervo
# Processing Record 1 of Set 6 | provideniya
# Processing Record 1 of Set 6 | caninde de sao francisco
# Processing Record 1 of Set 6 | ngunguru
# Processing Record 1 of Set 6 | rawicz
# Processing Record 1 of Set 6 | cabedelo
# Processing Record 1 of Set 6 | charters towers
# Processing Record 1 of Set 6 | karagay
# Processing Record 1 of Set 6 | upernavik
# Processing Record 1 of Set 6 | roshchino
# Processing Record 1 of Set 6 | iralaya
# Processing Record 1 of Set 6 | peniche
# Processing Record 1 of Set 6 | djibo
# Processing Record 1 of Set 6 | sosnovo-ozerskoye
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 1 of Set 6 | saint george
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 1 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 6 | coffs harbour
# Processing Record 1 of Set 6 | oranjestad
# Processing Record 1 of Set 6 | atambua
# Processing Record 1 of Set 6 | deputatskiy
# Processing Record 1 of Set 6 | hami
# Processing Record 1 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 6 | itarema
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 1 of Set 6 | hailar
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 6 | chara
# Processing Record 1 of Set 7 | cap-aux-meules
# Processing Record 1 of Set 7 | saint-philippe
# Processing Record 1 of Set 7 | borger
# Processing Record 1 of Set 7 | kruisfontein
# Processing Record 1 of Set 7 | sochi
# Processing Record 1 of Set 7 | simpang
# Processing Record 1 of Set 7 | thompson
# Processing Record 1 of Set 7 | desterro
# Processing Record 1 of Set 7 | sheridan
# Processing Record 1 of Set 7 | oranjemund
# Processing Record 1 of Set 7 | banda aceh
# Processing Record 1 of Set 7 | qaqortoq
# Processing Record 1 of Set 7 | belmonte
# Processing Record 1 of Set 7 | mount isa
# Processing Record 1 of Set 7 | sisimiut
# Processing Record 1 of Set 7 | daru
# Processing Record 1 of Set 7 | san antonio
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 1 of Set 7 | olafsvik
# Processing Record 1 of Set 7 | tarko-sale
# Processing Record 1 of Set 7 | college
# Processing Record 1 of Set 7 | borogontsy
# Processing Record 1 of Set 7 | codrington
# Processing Record 1 of Set 7 | zhigansk
# Processing Record 1 of Set 7 | faanui
# Processing Record 1 of Set 7 | ahuimanu
# Processing Record 1 of Set 7 | dingle
# Processing Record 1 of Set 7 | lorengau
# Processing Record 1 of Set 7 | adre
# Processing Record 1 of Set 7 | beisfjord
# Processing Record 1 of Set 7 | xinye
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 1 of Set 7 | porto santo
# Processing Record 1 of Set 7 | coquimbo
# Processing Record 1 of Set 7 | tura
# Processing Record 1 of Set 7 | syasstroy
# Processing Record 1 of Set 7 | weiser
# Processing Record 1 of Set 7 | ailigandi
# Processing Record 1 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 7 | puro
# Processing Record 1 of Set 7 | salalah
# Processing Record 1 of Set 7 | samarinda
# Processing Record 1 of Set 7 | kosonsoy
# Processing Record 1 of Set 7 | sur
# Processing Record 1 of Set 7 | mondovi
# Processing Record 1 of Set 7 | borujan
# City not found. Skipping...
# Processing Record 1 of Set 7 | sinnamary
# Processing Record 1 of Set 7 | vardo
# Processing Record 1 of Set 7 | narrabri
# Processing Record 1 of Set 8 | beringovskiy
# Processing Record 1 of Set 8 | san quintin
# Processing Record 1 of Set 8 | natitingou
# Processing Record 1 of Set 8 | vuktyl
# Processing Record 1 of Set 8 | dieppe
# Processing Record 1 of Set 8 | tiszaeszlar
# Processing Record 1 of Set 8 | hounde
# Processing Record 1 of Set 8 | plastun
# Processing Record 1 of Set 8 | flin flon
# Processing Record 1 of Set 8 | hurricane
# Processing Record 1 of Set 8 | ponta do sol
# Processing Record 1 of Set 8 | honningsvag
# Processing Record 1 of Set 8 | dombarovskiy
# Processing Record 1 of Set 8 | awbari
# Processing Record 1 of Set 8 | klyuchi
# Processing Record 1 of Set 8 | marawi
# Processing Record 1 of Set 8 | addi ugri
# City not found. Skipping...
# Processing Record 1 of Set 8 | birao
# Processing Record 1 of Set 8 | namibe
# Processing Record 1 of Set 8 | fomboni
# Processing Record 1 of Set 8 | davila
# Processing Record 1 of Set 8 | hilton head island
# Processing Record 1 of Set 8 | srebrenica
# Processing Record 1 of Set 8 | caucaia
# Processing Record 1 of Set 8 | guerrero negro
# Processing Record 1 of Set 8 | languyan
# Processing Record 1 of Set 8 | saint-francois
# Processing Record 1 of Set 8 | resistencia
# Processing Record 1 of Set 8 | yulara
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 1 of Set 8 | san lawrenz
# Processing Record 1 of Set 8 | dali
# Processing Record 1 of Set 8 | mattawa
# Processing Record 1 of Set 8 | eskisehir
# Processing Record 1 of Set 8 | atikokan
# Processing Record 1 of Set 8 | camacupa
# Processing Record 1 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 8 | bulgan
# Processing Record 1 of Set 8 | nanortalik
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 1 of Set 8 | abu kamal
# Processing Record 1 of Set 8 | broome
# Processing Record 1 of Set 8 | severnoye
# Processing Record 1 of Set 8 | rock sound
# Processing Record 1 of Set 8 | jawhar
# Processing Record 1 of Set 8 | port elizabeth
# Processing Record 1 of Set 8 | port lincoln
# Processing Record 1 of Set 8 | yuxia
# Processing Record 1 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 8 | sena madureira
# Processing Record 1 of Set 9 | maceio
# Processing Record 1 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 1 of Set 9 | orlik
# Processing Record 1 of Set 9 | port hardy
# Processing Record 1 of Set 9 | arman
# Processing Record 1 of Set 9 | jijiga
# Processing Record 1 of Set 9 | sar-e pul
# Processing Record 1 of Set 9 | hasaki
# Processing Record 1 of Set 9 | puerto madryn
# Processing Record 1 of Set 9 | villa rica
# Processing Record 1 of Set 9 | portland
# Processing Record 1 of Set 9 | menongue
# Processing Record 1 of Set 9 | palmer
# Processing Record 1 of Set 9 | nikolskoye
# Processing Record 1 of Set 9 | pevek
# Processing Record 1 of Set 9 | vila franca do campo
# Processing Record 1 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 9 | hofn
# Processing Record 1 of Set 9 | kysyl-syr
# Processing Record 1 of Set 9 | hovd
# Processing Record 1 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 9 | emilio carranza
# Processing Record 1 of Set 9 | torbay
# Processing Record 1 of Set 9 | manta
# Processing Record 1 of Set 9 | mar del plata
# Processing Record 1 of Set 9 | riyadh
# Processing Record 1 of Set 9 | gat
# Processing Record 1 of Set 9 | ketchikan
# Processing Record 1 of Set 9 | northam
# Processing Record 1 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 9 | huarmey
# Processing Record 1 of Set 9 | richards bay
# Processing Record 1 of Set 9 | nome
# Processing Record 1 of Set 9 | port macquarie
# Processing Record 1 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 9 | ossora
# Processing Record 1 of Set 9 | corinto
# Processing Record 1 of Set 9 | saint-joseph
# Processing Record 1 of Set 9 | joao pinheiro
# Processing Record 1 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 1 of Set 9 | alyangula
# Processing Record 1 of Set 9 | souillac
# Processing Record 1 of Set 9 | fort nelson
# Processing Record 1 of Set 9 | miles city
# Processing Record 1 of Set 9 | bonavista
# Processing Record 1 of Set 9 | hambantota
# Processing Record 1 of Set 9 | itoman
# Processing Record 1 of Set 9 | sao joao da barra
# Processing Record 1 of Set 9 | chateauroux
# Processing Record 1 of Set 9 | zdunska wola
# Processing Record 1 of Set 10 | enshi
# Processing Record 1 of Set 10 | dzaoudzi
# Processing Record 1 of Set 10 | liancheng
# Processing Record 1 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 10 | jamsa
# Processing Record 1 of Set 10 | tilichiki
# Processing Record 1 of Set 10 | pasighat
# Processing Record 1 of Set 10 | san juan
# Processing Record 1 of Set 10 | san jose
# Processing Record 1 of Set 10 | qingan
# City not found. Skipping...
# Processing Record 1 of Set 10 | abrau-dyurso
# Processing Record 1 of Set 10 | hargeysa
# Processing Record 1 of Set 10 | nuevo progreso
# Processing Record 1 of Set 10 | gillette
# Processing Record 1 of Set 10 | ahipara
# Processing Record 1 of Set 10 | caravelas
# Processing Record 1 of Set 10 | whitehaven
# Processing Record 1 of Set 10 | cascais
# Processing Record 1 of Set 10 | sorland
# Processing Record 1 of Set 10 | manali
# Processing Record 1 of Set 10 | tual
# Processing Record 1 of Set 10 | vallenar
# Processing Record 1 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 10 | magistralnyy
# Processing Record 1 of Set 10 | gerash
# Processing Record 1 of Set 10 | saint-augustin
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 1 of Set 10 | verkhoyansk
# Processing Record 1 of Set 10 | mandiana
# Processing Record 1 of Set 10 | kangaatsiaq
# Processing Record 1 of Set 10 | akyab
# Processing Record 1 of Set 10 | kopavogur
# Processing Record 1 of Set 10 | havre-saint-pierre
# Processing Record 1 of Set 10 | alofi
# Processing Record 1 of Set 10 | matara
# Processing Record 1 of Set 10 | ingham
# Processing Record 1 of Set 10 | alindao
# Processing Record 1 of Set 10 | zavetnoye
# Processing Record 1 of Set 10 | ust-nera
# Processing Record 1 of Set 10 | la ronge
# Processing Record 1 of Set 10 | saint pete beach
# Processing Record 1 of Set 10 | moussoro
# Processing Record 1 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 1 of Set 10 | puertollano
# Processing Record 1 of Set 10 | zhangzhou
# Processing Record 1 of Set 10 | barao de melgaco
# Processing Record 1 of Set 10 | norden
# Processing Record 1 of Set 10 | bundaberg
# Processing Record 1 of Set 10 | oktyabrskiy
# Processing Record 1 of Set 11 | correntina
# Processing Record 1 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | quincy
# Processing Record 1 of Set 11 | madisonville
# Processing Record 1 of Set 11 | eureka
# Processing Record 1 of Set 11 | puck
# Processing Record 1 of Set 11 | sola
# Processing Record 1 of Set 11 | arlit
# Processing Record 1 of Set 11 | lagos
# Processing Record 1 of Set 11 | saldanha
# Processing Record 1 of Set 11 | alihe
# Processing Record 1 of Set 11 | bubaque
# Processing Record 1 of Set 11 | port hawkesbury
# Processing Record 1 of Set 11 | padang
# Processing Record 1 of Set 11 | karistos
# City not found. Skipping...
# Processing Record 1 of Set 11 | penzance
# Processing Record 1 of Set 11 | guane
# Processing Record 1 of Set 11 | bujak
# Processing Record 1 of Set 11 | paita
# Processing Record 1 of Set 11 | hobyo
# Processing Record 1 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 1 of Set 11 | veraval
# Processing Record 1 of Set 11 | chadiza
# Processing Record 1 of Set 11 | le vauclin
# Processing Record 1 of Set 11 | santa rosa
# Processing Record 1 of Set 11 | vostok
# Processing Record 1 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 11 | bocana de paiwas
# Processing Record 1 of Set 11 | camacha
# Processing Record 1 of Set 11 | gambela
# Processing Record 1 of Set 11 | aykhal
# Processing Record 1 of Set 11 | karabudakhkent
# Processing Record 1 of Set 11 | viedma
# Processing Record 1 of Set 11 | mbandaka
# Processing Record 1 of Set 11 | pavelets
# Processing Record 1 of Set 11 | kavaratti
# Processing Record 1 of Set 11 | ulagan
# Processing Record 1 of Set 11 | miranda
# Processing Record 1 of Set 11 | pyaozerskiy
# Processing Record 1 of Set 11 | deyang
# Processing Record 1 of Set 11 | pacific grove
# Processing Record 1 of Set 11 | rodrigues alves
# Processing Record 1 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 11 | lompoc
# Processing Record 1 of Set 11 | thunder bay
# Processing Record 1 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 11 | erzin
# Processing Record 1 of Set 11 | igarka
# Processing Record 1 of Set 11 | inirida
# Processing Record 1 of Set 12 | islamkot
# Processing Record 1 of Set 12 | arequipa
# Processing Record 1 of Set 12 | rajpipla
# Processing Record 1 of Set 12 | poronaysk
# Processing Record 1 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 12 | olyka
# Processing Record 1 of Set 12 | southbridge
# Processing Record 1 of Set 12 | puerto colombia
# Processing Record 1 of Set 12 | broken hill
# Processing Record 1 of Set 12 | zlobin
# Processing Record 1 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 12 | anito
# Processing Record 1 of Set 12 | ambovombe
# Processing Record 1 of Set 12 | chifeng
# Processing Record 1 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 1 of Set 12 | laa
# Processing Record 1 of Set 12 | hay river
# Processing Record 1 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | berkovica
# Processing Record 1 of Set 12 | thinadhoo
# Processing Record 1 of Set 12 | visby
# Processing Record 1 of Set 12 | san diego de los banos
# Processing Record 1 of Set 12 | odesskoye
# Processing Record 1 of Set 12 | natulongan
# City not found. Skipping...
# Processing Record 1 of Set 12 | kodyma
# Processing Record 1 of Set 12 | magaria
# Processing Record 1 of Set 12 | kiryas joel
# Processing Record 1 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 1 of Set 12 | labuhan
# Processing Record 1 of Set 12 | yarada
# Processing Record 1 of Set 12 | tukrah
# Processing Record 1 of Set 12 | saiha
# Processing Record 1 of Set 12 | kondinskoye
# Processing Record 1 of Set 12 | myanaung
# Processing Record 1 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | poum
# Processing Record 1 of Set 12 | chernyshevskiy
# Processing Record 1 of Set 12 | sao sebastiao
# Processing Record 1 of Set 12 | vikhorevka
# Processing Record 1 of Set 12 | santa maria
# Processing Record 1 of Set 12 | silale
# Processing Record 1 of Set 12 | salinas
# Processing Record 1 of Set 12 | horodnytsya
# Processing Record 1 of Set 12 | namwala
# Processing Record 1 of Set 12 | kondoa
# Processing Record 1 of Set 12 | comodoro rivadavia
# Processing Record 1 of Set 12 | eyl
# Processing Record 1 of Set 12 | itaqui
# Processing Record 1 of Set 12 | kinablangan
# Processing Record 1 of Set 12 | fairview
# Processing Record 1 of Set 13 | carndonagh
# Processing Record 1 of Set 13 | misratah
# Processing Record 1 of Set 13 | moree
# Processing Record 1 of Set 13 | kapit
# Processing Record 1 of Set 13 | hearst
# Processing Record 1 of Set 13 | biu
# Processing Record 1 of Set 13 | ust-kuyga
# Processing Record 1 of Set 13 | bakchar
# Processing Record 1 of Set 13 | chiguiri arriba
# City not found. Skipping...
# Processing Record 1 of Set 13 | ribeira brava
# Processing Record 1 of Set 13 | puerto del rosario
# Processing Record 1 of Set 13 | lloret de mar
# Processing Record 1 of Set 13 | morro bay
# Processing Record 1 of Set 13 | vila velha
# Processing Record 1 of Set 13 | asmar
# Processing Record 1 of Set 13 | weinan
# Processing Record 1 of Set 13 | husavik
# Processing Record 1 of Set 13 | muros
# Processing Record 1 of Set 13 | ust-ilimsk
# Processing Record 1 of Set 13 | okhotsk
# Processing Record 1 of Set 13 | redcliffe
# Processing Record 1 of Set 13 | coahuayana
# Processing Record 1 of Set 13 | evensk
# Processing Record 1 of Set 13 | strezhevoy
# Processing Record 1 of Set 13 | kefamenanu
# Processing Record 1 of Set 13 | amapa
# Processing Record 1 of Set 13 | gisborne
# Processing Record 1 of Set 13 | biak
# Processing Record 1 of Set 13 | pauini
# Processing Record 1 of Set 13 | buala
# Processing Record 1 of Set 13 | rosa zarate
# Processing Record 1 of Set 13 | outram
# Processing Record 1 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 13 | ler
# Processing Record 1 of Set 13 | porto novo
# Processing Record 1 of Set 13 | beya
# Processing Record 1 of Set 13 | sheopur
# Processing Record 1 of Set 13 | natal
# Processing Record 1 of Set 13 | banepa
# Processing Record 1 of Set 13 | mezen
# Processing Record 1 of Set 13 | seoul
# Processing Record 1 of Set 13 | karasuk
# Processing Record 1 of Set 13 | viesca
# Processing Record 1 of Set 13 | santa isabel do rio negro
# Processing Record 1 of Set 13 | waslala
# Processing Record 1 of Set 13 | jibuti
# Processing Record 1 of Set 13 | paka
# Processing Record 1 of Set 13 | naugarzan
# City not found. Skipping...
# Processing Record 1 of Set 13 | hokitika
# Processing Record 1 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 14 | sorong
# Processing Record 1 of Set 14 | samandag
# Processing Record 1 of Set 14 | ambon
# Processing Record 1 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 14 | byron bay
# Processing Record 1 of Set 14 | mont-de-marsan
# Processing Record 1 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 14 | opuwo
# Processing Record 1 of Set 14 | muborak
# Processing Record 1 of Set 14 | tucuman
# Processing Record 1 of Set 14 | neulengbach
# Processing Record 1 of Set 14 | wangou
# Processing Record 1 of Set 14 | svetlogorsk
# Processing Record 1 of Set 14 | sangar
# Processing Record 1 of Set 14 | verkhnyaya inta
# Processing Record 1 of Set 14 | asyut
# Processing Record 1 of Set 14 | hit
# Processing Record 1 of Set 14 | khani
# Processing Record 1 of Set 14 | primorsk
# Processing Record 1 of Set 14 | sierpc
# Processing Record 1 of Set 14 | linxia
# Processing Record 1 of Set 14 | sukhobezvodnoye
# Processing Record 1 of Set 14 | powassan
# Processing Record 1 of Set 14 | bereda
# Processing Record 1 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 14 | launceston
# Processing Record 1 of Set 14 | of
# City not found. Skipping...
# Processing Record 1 of Set 14 | esparta
# Processing Record 1 of Set 14 | stornoway
# Processing Record 1 of Set 14 | belfast
# Processing Record 1 of Set 14 | soure
# Processing Record 1 of Set 14 | barcelos
# Processing Record 1 of Set 14 | sabang
# Processing Record 1 of Set 14 | zhanaozen
# Processing Record 1 of Set 14 | jining
# Processing Record 1 of Set 14 | bandarbeyla
# Processing Record 1 of Set 14 | flinders
# Processing Record 1 of Set 14 | brae
# Processing Record 1 of Set 14 | tessalit
# Processing Record 1 of Set 14 | nenjiang
# Processing Record 1 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 1 of Set 14 | chengde
# Processing Record 1 of Set 14 | maracacume
# Processing Record 1 of Set 14 | antalaha
# Processing Record 1 of Set 14 | lincoln
# Processing Record 1 of Set 14 | umba
# Processing Record 1 of Set 14 | srednekolymsk
# Processing Record 1 of Set 14 | castro alves
# Processing Record 1 of Set 14 | dongfeng
# Processing Record 1 of Set 15 | karratha
# Processing Record 1 of Set 15 | spring valley
# Processing Record 1 of Set 15 | pingliang
# Processing Record 1 of Set 15 | hailey
# Processing Record 1 of Set 15 | umm kaddadah
# Processing Record 1 of Set 15 | atar
# Processing Record 1 of Set 15 | phalombe
# Processing Record 1 of Set 15 | oni
# Processing Record 1 of Set 15 | kardla
# Processing Record 1 of Set 15 | ayagoz
# Processing Record 1 of Set 15 | hukuntsi
# Processing Record 1 of Set 15 | touros
# Processing Record 1 of Set 15 | rupert
# Processing Record 1 of Set 15 | zhireken
# Processing Record 1 of Set 15 | molina
# Processing Record 1 of Set 15 | wadowice
# Processing Record 1 of Set 15 | othonoi
# City not found. Skipping...
# Processing Record 1 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 15 | kirundo
# Processing Record 1 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 1 of Set 15 | georgiyevka
# Processing Record 1 of Set 15 | tenosique
# Processing Record 1 of Set 15 | waipawa
# Processing Record 1 of Set 15 | kiri buru
# Processing Record 1 of Set 15 | monte alegre
# Processing Record 1 of Set 15 | klaeng
# Processing Record 1 of Set 15 | santa fe
# Processing Record 1 of Set 15 | wamba
# Processing Record 1 of Set 15 | shaowu
# Processing Record 1 of Set 15 | barbastro
# Processing Record 1 of Set 15 | rassvet
# Processing Record 1 of Set 15 | samfya
# Processing Record 1 of Set 15 | kalianget
# Processing Record 1 of Set 15 | puerto escondido
# Processing Record 1 of Set 15 | am timan
# Processing Record 1 of Set 15 | gitarama
# Processing Record 1 of Set 15 | guarapari
# Processing Record 1 of Set 15 | wagga wagga
# Processing Record 1 of Set 15 | ocampo
# Processing Record 1 of Set 15 | whitehorse
# Processing Record 1 of Set 15 | manggar
# Processing Record 1 of Set 15 | nacogdoches
# Processing Record 1 of Set 15 | manjeshwar
# Processing Record 1 of Set 15 | abu samrah
# Processing Record 1 of Set 15 | immenstadt
# Processing Record 1 of Set 15 | gelnica
# Processing Record 1 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 15 | bilma
# Processing Record 1 of Set 15 | dana point
# Processing Record 1 of Set 15 | saint-gaudens
# Processing Record 1 of Set 16 | goderich
# Processing Record 1 of Set 16 | lichinga
# Processing Record 1 of Set 16 | janauba
# Processing Record 1 of Set 16 | yatou
# Processing Record 1 of Set 16 | sicuani
# Processing Record 1 of Set 16 | auki
# Processing Record 1 of Set 16 | douglas
# Processing Record 1 of Set 16 | lamu
# Processing Record 1 of Set 16 | anloga
# Processing Record 1 of Set 16 | proletariy
# Processing Record 1 of Set 16 | ijaki
# City not found. Skipping...
# Processing Record 1 of Set 16 | rundu
# Processing Record 1 of Set 16 | crimmitschau
# Processing Record 1 of Set 16 | kibondo
# Processing Record 1 of Set 16 | ranong
# Processing Record 1 of Set 16 | raudeberg
# Processing Record 1 of Set 16 | nemuro
# Processing Record 1 of Set 16 | sharkan
# Processing Record 1 of Set 16 | mutoko
# Processing Record 1 of Set 16 | half moon bay
# Processing Record 1 of Set 16 | naze
# Processing Record 1 of Set 16 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Port Alfred -33.5906   26.8910     52.57        73          15
# 1  Lake Saint Louis  38.7976  -90.7857     85.95        71          20
# 2       Clyde River  70.4692  -68.5914     35.83       100         100
# 3         Cape Town -33.9258   18.4232     56.37        76           0
# 4              Hilo  19.7297 -155.0900     85.28        67           0
#
#    Wind Speed Country                 Date
# 0       10.71      ZA  2022-08-01 00:26:54
# 1        4.61      US  2022-08-01 00:26:55
# 2        4.61      CA  2022-08-01 00:26:55
# 3        8.01      ZA  2022-08-01 00:25:26
# 4       13.80      US  2022-08-01 00:26:55

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
